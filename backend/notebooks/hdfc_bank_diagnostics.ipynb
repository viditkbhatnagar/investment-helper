# %% [markdown]
# # HDFC Bank diagnostics: 10-year return modeling with LSTM + LightGBM
#
# This notebook pulls data for a single company from MongoDB, builds the same features used by the API (MACD, RSI, MAs, momentum, volatility, proximity), appends exogenous signals from database collections, and trains:
#
# - A return-based LightGBM model on the last 10 years (with StandardScaler)
# - A return-based LSTM (if TensorFlow is available; otherwise a linear fallback)
#
# Predictions are made for horizons h in {1, 5, 10} and re-anchored to the latest close. Final outputs include model components and a volatility-clamped ensemble estimate.

# %%
# Setup
import os
import json
import math
import numpy as np
import pandas as pd
from pymongo import MongoClient
from datetime import datetime, timedelta

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression

try:
    import lightgbm as lgb
except Exception:
    lgb = None

try:
    import tensorflow as tf
    from tensorflow import keras
    TF_AVAILABLE = True
except Exception:
    TF_AVAILABLE = False

MONGO_URI = os.getenv("MONGODB_URI", "mongodb://localhost:27017")
DB_CACHE = os.getenv("MONGODB_CACHE_DB", "investment_advisor_cache")
client = MongoClient(MONGO_URI)
db = client[DB_CACHE]

NAME = "Hdfc Bank"
LNAME = NAME.strip().lower()
HORIZONS = [1, 5, 10]

# %%
# Load 10-year historical series and signals

def extract_price_series(doc: dict) -> pd.DataFrame:
    datasets = (doc or {}).get("datasets", [])
    price_ds = next((ds for ds in datasets if str(ds.get("metric", "")).lower() == "price" or str(ds.get("label", "")).lower().startswith("price")), None)
    if not price_ds:
        return pd.DataFrame()
    rows = price_ds.get("values", [])
    dt, val = [], []
    for r in rows:
        if len(r) >= 2:
            dt.append(pd.to_datetime(r[0]))
            try:
                val.append(float(r[1]))
            except Exception:
                val.append(np.nan)
    df = pd.DataFrame({"date": dt, "close": val}).dropna()
    df.sort_values("date", inplace=True)
    df.set_index("date", inplace=True)
    return df

hist = db.historical_data.find_one({"_norm_name": LNAME, "_period": "10yr", "_filter": "price"}) or db.historical_data.find_one({"_norm_name": LNAME}) or {}
prices = extract_price_series(hist)
print("History rows:", len(prices))

# Auxiliary collections
fifty = db.fiftytwo_week.find_one({}) or {}
ann = db.recent_announcements.find_one({"_norm_name": LNAME}) or {}
corp = db.corporate_actions.find_one({"_norm_name": LNAME}) or {}
details = db.stock_details.find_one({"_norm_name": LNAME}) or {}
stats_doc = db.historical_stats.find_one({"_norm_name": LNAME}) or {}
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[10], line 22
#      19     df.set_index("date", inplace=True)
#      20     return df
# ---> 22 hist = db.historical_data.find_one({"_norm_name": LNAME, "_period": "10yr", "_filter": "price"}) or db.historical_data.find_one({"_norm_name": LNAME}) or {}
#      23 prices = extract_price_series(hist)
#      24 print("History rows:", len(prices))
#
# File ~/codes/investment-advisor/.venv/lib/python3.13/site-packages/pymongo/synchronous/collection.py:1709, in Collection.find_one(self, filter, *args, **kwargs)
#    1707     filter = {"_id": filter}
#    1708 cursor = self.find(filter, *args, **kwargs)
# -> 1709 for result in cursor.limit(-1):
#    1710     return result
#    1711 return None
#
# File ~/codes/investment-advisor/.venv/lib/python3.13/site-packages/pymongo/synchronous/cursor.py:1281, in Cursor.__next__(self)
#    1280 def __next__(self) -> _DocumentType:
# -> 1281     return self.next()
#
# File ~/codes/investment-advisor/.venv/lib/python3.13/site-packages/pymongo/synchronous/cursor.py:1257, in Cursor.next(self)
#    1255 if self._empty:
#    1256     raise StopIteration
# -> 1257 if len(self._data) or self._refresh():
#    1258     return self._data.popleft()
#    1259 else:
#
# File ~/codes/investment-advisor/.venv/lib/python3.13/site-packages/pymongo/synchronous/cursor.py:1205, in Cursor._refresh(self)
#    1183         raise InvalidOperation(
#    1184             "Passing a 'hint' is required when using the min/max query"
#    1185             " option to ensure the query utilizes the correct index"
#    1186         )
#    1187     q = self._query_class(
#    1188         self._query_flags,
#    1189         self._collection.database.name,
#    (...)   1203         self._exhaust,
#    1204     )
# -> 1205     self._send_message(q)
#    1206 elif self._id:  # Get More
#    1207     if self._limit:
#
# File ~/codes/investment-advisor/.venv/lib/python3.13/site-packages/pymongo/synchronous/cursor.py:1100, in Cursor._send_message(self, operation)
#    1097     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1099 try:
# -> 1100     response = client._run_operation(
#    1101         operation, self._unpack_response, address=self._address
#    1102     )
#    1103 except OperationFailure as exc:
#    1104     if exc.code in _CURSOR_CLOSED_ERRORS or self._exhaust:
#    1105         # Don't send killCursors because the cursor is already closed.
#
# File ~/codes/investment-advisor/.venv/lib/python3.13/site-packages/pymongo/_csot.py:120, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     118         with _TimeoutContext(timeout):
#     119             return func(self, *args, **kwargs)
# --> 120 return func(self, *args, **kwargs)
#
# File ~/codes/investment-advisor/.venv/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:1754, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1744     operation.reset()  # Reset op in case of retry.
#    1745     return server.run_operation(
#    1746         conn,
#    1747         operation,
#    (...)   1751         self,
#    1752     )
# -> 1754 return self._retryable_read(
#    1755     _cmd,
#    1756     operation.read_preference,
#    1757     operation.session,  # type: ignore[arg-type]
#    1758     address=address,
#    1759     retryable=isinstance(operation, _Query),
#    1760     operation=operation.name,
#    1761 )
#
# File ~/codes/investment-advisor/.venv/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:1863, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    1858 # Ensure that the client supports retrying on reads and there is no session in
#    1859 # transaction, otherwise, we will not support retry behavior for this call.
#    1860 retryable = bool(
#    1861     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    1862 )
# -> 1863 return self._retry_internal(
#    1864     func,
#    1865     session,
#    1866     None,
#    1867     operation,
#    1868     is_read=True,
#    1869     address=address,
#    1870     read_pref=read_pref,
#    1871     retryable=retryable,
#    1872     operation_id=operation_id,
#    1873 )
#
# File ~/codes/investment-advisor/.venv/lib/python3.13/site-packages/pymongo/_csot.py:120, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     118         with _TimeoutContext(timeout):
#     119             return func(self, *args, **kwargs)
# --> 120 return func(self, *args, **kwargs)
#
# File ~/codes/investment-advisor/.venv/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:1830, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1793 @_csot.apply
#    1794 def _retry_internal(
#    1795     self,
#    (...)   1804     operation_id: Optional[int] = None,
#    1805 ) -> T:
#    1806     """Internal retryable helper for all client transactions.
#    1807
#    1808     :param func: Callback function we want to retry
#    (...)   1817     :return: Output of the calling func()
#    1818     """
#    1819     return _ClientConnectionRetryable(
#    1820         mongo_client=self,
#    1821         func=func,
#    1822         bulk=bulk,
#    1823         operation=operation,
#    1824         is_read=is_read,
#    1825         session=session,
#    1826         read_pref=read_pref,
#    1827         address=address,
#    1828         retryable=retryable,
#    1829         operation_id=operation_id,
# -> 1830     ).run()
#
# File ~/codes/investment-advisor/.venv/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:2554, in _ClientConnectionRetryable.run(self)
#    2552 self._check_last_error(check_csot=True)
#    2553 try:
# -> 2554     return self._read() if self._is_read else self._write()
#    2555 except ServerSelectionTimeoutError:
#    2556     # The application may think the write was never attempted
#    2557     # if we raise ServerSelectionTimeoutError on the retry
#    2558     # attempt. Raise the original exception instead.
#    2559     self._check_last_error()
#
# File ~/codes/investment-advisor/.venv/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:2689, in _ClientConnectionRetryable._read(self)
#    2684 def _read(self) -> T:
#    2685     """Wrapper method for read-type retryable client executions
#    2686
#    2687     :return: Output for func()'s call
#    2688     """
# -> 2689     self._server = self._get_server()
#    2690     assert self._read_pref is not None, "Read Preference required on read calls"
#    2691     with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#    2692         conn,
#    2693         read_pref,
#    2694     ):
#
# File ~/codes/investment-advisor/.venv/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:2645, in _ClientConnectionRetryable._get_server(self)
#    2640 def _get_server(self) -> Server:
#    2641     """Retrieves a server object based on provided object context
#    2642
#    2643     :return: Abstraction to connect to server
#    2644     """
# -> 2645     return self._client._select_server(
#    2646         self._server_selector,
#    2647         self._session,
#    2648         self._operation,
#    2649         address=self._address,
#    2650         deprioritized_servers=self._deprioritized_servers,
#    2651         operation_id=self._operation_id,
#    2652     )
#
# File ~/codes/investment-advisor/.venv/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:1649, in MongoClient._select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1647             raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1648     else:
# -> 1649         server = topology.select_server(
#    1650             server_selector,
#    1651             operation,
#    1652             deprioritized_servers=deprioritized_servers,
#    1653             operation_id=operation_id,
#    1654         )
#    1655     return server
#    1656 except PyMongoError as exc:
#    1657     # Server selection errors in a transaction are transient.
#
# File ~/codes/investment-advisor/.venv/lib/python3.13/site-packages/pymongo/synchronous/topology.py:398, in Topology.select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     388 def select_server(
#     389     self,
#     390     selector: Callable[[Selection], Selection],
#    (...)    395     operation_id: Optional[int] = None,
#     396 ) -> Server:
#     397     """Like select_servers, but choose a random server if several match."""
# --> 398     server = self._select_server(
#     399         selector,
#     400         operation,
#     401         server_selection_timeout,
#     402         address,
#     403         deprioritized_servers,
#     404         operation_id=operation_id,
#     405     )
#     406     if _csot.get_timeout():
#     407         _csot.set_rtt(server.description.min_round_trip_time)
#
# File ~/codes/investment-advisor/.venv/lib/python3.13/site-packages/pymongo/synchronous/topology.py:376, in Topology._select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     367 def _select_server(
#     368     self,
#     369     selector: Callable[[Selection], Selection],
#    (...)    374     operation_id: Optional[int] = None,
#     375 ) -> Server:
# --> 376     servers = self.select_servers(
#     377         selector, operation, server_selection_timeout, address, operation_id
#     378     )
#     379     servers = _filter_servers(servers, deprioritized_servers)
#     380     if len(servers) == 1:
#
# File ~/codes/investment-advisor/.venv/lib/python3.13/site-packages/pymongo/synchronous/topology.py:283, in Topology.select_servers(self, selector, operation, server_selection_timeout, address, operation_id)
#     280     server_timeout = server_selection_timeout
#     282 with self._lock:
# --> 283     server_descriptions = self._select_servers_loop(
#     284         selector, server_timeout, operation, operation_id, address
#     285     )
#     287     return [
#     288         cast(Server, self.get_server_by_address(sd.address)) for sd in server_descriptions
#     289     ]
#
# File ~/codes/investment-advisor/.venv/lib/python3.13/site-packages/pymongo/synchronous/topology.py:333, in Topology._select_servers_loop(self, selector, timeout, operation, operation_id, address)
#     322     if _SERVER_SELECTION_LOGGER.isEnabledFor(logging.DEBUG):
#     323         _debug_log(
#     324             _SERVER_SELECTION_LOGGER,
#     325             message=_ServerSelectionStatusMessage.FAILED,
#    (...)    331             failure=self._error_message(selector),
#     332         )
# --> 333     raise ServerSelectionTimeoutError(
#     334         f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     335     )
#     337 if not logged_waiting:
#     338     _debug_log(
#     339         _SERVER_SELECTION_LOGGER,
#     340         message=_ServerSelectionStatusMessage.WAITING,
#    (...)    346         remainingTimeMS=int(end_time - time.monotonic()),
#     347     )
#
# ServerSelectionTimeoutError: localhost:27017: [Errno 61] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 689cdbb01846c4a61e6499f8, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 61] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>

# %%
# Feature builder (match backend logic with extras)

def build_features(df: pd.DataFrame) -> pd.DataFrame:
    if df.empty:
        return df
    out = df.copy()
    out["ret_1d"] = out["close"].pct_change()
    out["dma_20"] = out["close"].rolling(20).mean()
    out["dma_50"] = out["close"].rolling(50).mean()
    out["dma_100"] = out["close"].rolling(100).mean()
    out["dma_200"] = out["close"].rolling(200).mean()
    out["vol_20"] = out["ret_1d"].rolling(20).std()
    out["mom_10"] = out["close"].pct_change(10)
    out["close_over_dma20"] = out["close"] / out["dma_20"]
    out["close_over_dma50"] = out["close"] / out["dma_50"]
    out["close_over_dma100"] = out["close"] / out["dma_100"]
    out["close_over_dma200"] = out["close"] / out["dma_200"]
    out["roll_max_60"] = out["close"].rolling(60).max()
    out["roll_min_60"] = out["close"].rolling(60).min()
    denom = (out["roll_max_60"] - out["roll_min_60"]).replace(0, np.nan)
    out["prox_roll_60"] = (out["close"] - (out["roll_min_60"] + out["roll_max_60"]) / 2) / denom
    # RSI 14
    delta = out["close"].diff()
    gain = delta.clip(lower=0.0)
    loss = -delta.clip(upper=0.0)
    out["rsi_14"] = 100 - (100 / (1 + (gain.rolling(14).mean() / loss.rolling(14).mean().replace(0, np.nan))))
    # MACD
    ema12 = out["close"].ewm(span=12, adjust=False).mean()
    ema26 = out["close"].ewm(span=26, adjust=False).mean()
    macd = ema12 - ema26
    out["macd"] = macd
    out["macd_signal"] = macd.ewm(span=9, adjust=False).mean()
    out["macd_hist"] = out["macd"] - out["macd_signal"]
    return out.replace([np.inf, -np.inf], np.nan).dropna()

feats = build_features(prices)
print("Features shape:", feats.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 36
#      33     out["macd_hist"] = out["macd"] - out["macd_signal"]
#      34     return out.replace([np.inf, -np.inf], np.nan).dropna()
# ---> 36 feats = build_features(prices)
#      37 print("Features shape:", feats.shape)
#
# NameError: name 'prices' is not defined

# %%
# Build exogenous vector from DB signals (snapshot style)

def safe_num(x, default=0.0):
    try:
        v = float(x)
        if math.isfinite(v):
            return v
        return default
    except Exception:
        return default

# 52-week proximity (if present)
prox_52w = 0.0
for sec in ["BSE_52WeekHighLow", "NSE_52WeekHighLow", "bse_52weekhighlow", "nse_52weekhighlow"]:
    block = fifty.get(sec, {}) if isinstance(fifty, dict) else {}
    for cat in ("high52Week", "low52Week", "high52week", "low52week"):
        rows = block.get(cat, []) if isinstance(block, dict) else []
        for r in rows:
            if isinstance(r, dict) and str(r.get("company", "")).strip().lower().startswith(LNAME[:6]):
                price = safe_num(r.get("price") or r.get("Price"))
                h = safe_num(r.get("52_week_high") or r.get("high"), price)
                l = safe_num(r.get("52_week_low") or r.get("low"), price)
                if h and l:
                    prox_52w = 2 * (price - (l + h) / 2) / max(1e-6, (h - l))
                break

risk = safe_num(((details.get("riskMeter") or {}).get("score") if isinstance(details.get("riskMeter"), dict) else details.get("riskMeter")), 0.0)
# Sales growth slope (approx)
sales_growth = 0.0
q = (stats_doc.get("quarter_results") or stats_doc.get("Sales") or stats_doc.get("quarterResults")) if isinstance(stats_doc, dict) else {}
if isinstance(q, dict):
    try:
        series = list(q.get("Sales", {}).items()) if "Sales" in q else list(q.items())
        vals = [safe_num(v) for _, v in series[-6:]]
        if len(vals) >= 2 and abs(vals[0]) > 1e-6:
            sales_growth = (vals[-1] - vals[0]) / abs(vals[0])
    except Exception:
        pass

# Corporate events count
corp_events = 0
if isinstance(corp, dict):
    for k, v in corp.items():
        if k.endswith("meetings") and isinstance(v, dict):
            data = v.get("data", [])
            if isinstance(data, list):
                corp_events += len(data)

exog = {
    "feat_prox_52w": float(np.clip(prox_52w, -3.0, 3.0)),
    "feat_risk_meter": float(np.clip(risk, 0.0, 10.0)),
    "feat_sales_growth": float(np.clip(sales_growth, -3.0, 3.0)),
    "feat_corp_events": float(corp_events),
}

exog
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 15
#      13 prox_52w = 0.0
#      14 for sec in ["BSE_52WeekHighLow", "NSE_52WeekHighLow", "bse_52weekhighlow", "nse_52weekhighlow"]:
# ---> 15     block = fifty.get(sec, {}) if isinstance(fifty, dict) else {}
#      16     for cat in ("high52Week", "low52Week", "high52week", "low52week"):
#      17         rows = block.get(cat, []) if isinstance(block, dict) else []
#
# NameError: name 'fifty' is not defined

# %%
# Supervised matrices for returns

def append_exog(df: pd.DataFrame, exog: dict) -> pd.DataFrame:
    out = df.copy()
    for k, v in (exog or {}).items():
        try:
            out[k] = float(v)
        except Exception:
            out[k] = 0.0
    return out


def prepare_supervised(feats: pd.DataFrame, h: int, exog: dict):
    data = append_exog(feats, exog)
    data["target"] = (data["close"].shift(-h) / data["close"]) - 1.0
    data = data.dropna()
    X = data.drop(columns=["target"])  # keep full feature list
    y = data["target"].values
    return X, y, list(X.columns), data

X5, y5, cols, data5 = prepare_supervised(feats, 5, exog)
print(len(data5), "samples", len(cols), "features")

# %%
# Train LightGBM return model (or linear fallback)

scaler = StandardScaler()
Xs = scaler.fit_transform(X5.values)
split = int(len(Xs) * 0.8)

if lgb is not None and len(Xs) > 150:
    train = lgb.Dataset(Xs[:split], label=y5[:split])
    valid = lgb.Dataset(Xs[split:], label=y5[split:])
    params = {"objective": "regression", "metric": "l1", "verbosity": -1, "num_leaves": 63, "learning_rate": 0.05, "feature_fraction": 0.9}
    lgbm = lgb.train(params, train, num_boost_round=600, valid_sets=[valid])
    preds = lgbm.predict(Xs[split:])
else:
    lgbm = Pipeline([("lin", LinearRegression())]).fit(Xs[:split], y5[:split])
    preds = lgbm.predict(Xs[split:])

mae_val = float(mean_absolute_error(y5[split:], preds)) if split < len(Xs) else float("nan")
mae_val

# %%
# Train simple LSTM on returns (optional)

def build_seq(data: pd.DataFrame, cols: list[str], seq_len: int):
    vals = data[cols + ["target"]].values
    X_list, y_list = [], []
    for i in range(seq_len, len(vals)):
        X_list.append(vals[i-seq_len:i, :-1])
        y_list.append(vals[i, -1])
    return np.array(X_list), np.array(y_list)

seq_len = 30
lstm_mae = np.nan
lstm_pred = np.nan
if TF_AVAILABLE and len(data5) > seq_len + 50:
    # normalize by training stats only
    scaler_lstm = StandardScaler().fit(data5[cols].iloc[:split].values)
    train_n = scaler_lstm.transform(data5[cols].iloc[:split].values)
    val_n = scaler_lstm.transform(data5[cols].iloc[split:].values)
    data5n = pd.DataFrame(np.vstack([train_n, val_n]), index=data5.index, columns=cols)
    data5n["target"] = y5

    Xtr, ytr = build_seq(data5n.iloc[:split], cols, seq_len)
    Xva, yva = build_seq(data5n.iloc[split:], cols, seq_len)

    model = keras.Sequential([
        keras.layers.LSTM(128, return_sequences=True, input_shape=(seq_len, len(cols))),
        keras.layers.Dropout(0.2),
        keras.layers.LSTM(64),
        keras.layers.Dropout(0.2),
        keras.layers.Dense(1, activation="tanh"),
        keras.layers.Lambda(lambda x: 0.15 * x),
    ])
    model.compile(optimizer=keras.optimizers.Adam(1e-3), loss="mae", metrics=[keras.metrics.MAE])
    model.fit(Xtr, ytr, validation_data=(Xva, yva), epochs=20, verbose=0)
    lstm_mae = float(model.evaluate(Xva, yva, verbose=0)[1])
    # last seq prediction anchored to price
    last_seq = scaler_lstm.transform(data5[cols].iloc[-seq_len:].values)
    ret_hat = float(model.predict(last_seq[np.newaxis, :, :], verbose=0)[0][0])
    last_close = float(feats["close"].iloc[-1])
    lstm_pred = last_close * (1.0 + ret_hat)

lstm_mae, lstm_pred

# %%
# Compose ensemble for horizons and print diagnostics

last_close = float(feats["close"].iloc[-1])
ret_series = feats["close"].pct_change().dropna()
daily_vol = float(ret_series.rolling(20).std().iloc[-1]) if len(ret_series) > 20 else float(ret_series.std())

results = {}
for h in HORIZONS:
    Xh, yh, colsh, datah = prepare_supervised(feats, h, exog)
    Xsh = scaler.transform(Xh.values)
    # LightGBM/linear prediction for last row
    last_row = Xsh[-1:]
    ret_hat_lgbm = float(lgbm.predict(last_row)[0]) if hasattr(lgbm, "predict") else 0.0
    pt_lgbm = last_close * (1.0 + ret_hat_lgbm)
    # Combine with LSTM if available
    w_lgbm = 1.0 / max(1e-6, mae_val * last_close)
    w_lstm = 1.0 / max(1e-6, lstm_mae * last_close) if TF_AVAILABLE and math.isfinite(lstm_mae) else 0.0
    if not math.isfinite(w_lstm) or w_lstm == 0.0:
        w_lstm = 0.0
    if not math.isfinite(w_lgbm):
        w_lgbm = 1.0
    w_sum = w_lgbm + w_lstm if (w_lgbm + w_lstm) > 0 else 1.0
    p50 = (w_lgbm * pt_lgbm + w_lstm * (lstm_pred if math.isfinite(lstm_pred) else pt_lgbm)) / w_sum
    # clamp
    band = last_close * (daily_vol * max(1.0, (h ** 0.5)) * 2.5)
    lo = max(0.0, last_close - band)
    hi = last_close + band
    p50 = float(np.clip(p50, lo, hi))
    results[h] = {"last_close": last_close, "p50": p50, "lgbm": pt_lgbm, "lstm": float(lstm_pred) if math.isfinite(lstm_pred) else None, "vol_band": [lo, hi], "daily_vol": daily_vol, "mae_lgbm": mae_val, "mae_lstm": float(lstm_mae) if math.isfinite(lstm_mae) else None}

results
